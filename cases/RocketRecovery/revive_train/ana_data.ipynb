# %%
import numpy as np
import pandas as pd

# %%
data = dict(np.load("./data/rocketrecovery.npz"))
data = pd.DataFrame(data["engine_power"],columns=["engine_power_0","engine_power_1"])

# %%
data["engine_power_0"].hist(bins=100)
# Out:
# <Axes: >

# %%
data["engine_power_1"].hist(bins=100)
# Out:
# <Axes: >
